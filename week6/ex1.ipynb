# %%
for x in range(6):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(2, 10, 2):
    print(x)
# Out:
# 2
# 4
# 6
# 8

# %%
for x in range(6):
    if x == 3: 
        break
    print(x)
else:
    print("Finally Finnish")
# Out:
# 0
# 1
# 2

# %%
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "berry"]
for i in fruits :

    j=0
    print(i, "is color", adj[j])
    j+1
# Out:
# apple is color red
# banana is color red
# berry is color red

# %%
fruits = []
adj = []
loop = True
while loop:

    inp1 = input("Fruit name is? : ")
    inp2 = input("color name is : ")
    adj.append(inp2)

    inpcheck = input("Enter a fruit name")
    inpcheck = input("Enter a color name")
    if inpcheck != 'y':
        loop = False

# %%
for i in fruits:
    print(i, "is color", adj[fruits.index(i)])

# %%
x = lambda a : a + 10
print(x(5))
x = lambda a , b , c : a * b + c
print(x(2, 3, 4))
# Out:
# 15
# 10

# %%
data = [("apple", 5), ("banana", 2), ("cherry", 9)]

data.sort(key=lambda x:x[1])
print("sorted by Number : ", data)
# Out:
# sorted by Number :  [('banana', 2), ('apple', 5), ('cherry', 9)]
