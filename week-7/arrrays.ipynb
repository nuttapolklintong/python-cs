# %%
cars = ["Ford", "Volvo", "BMW"]
cars_copy = cars.copy()
print("Backup data", cars_copy)

print(cars)

cars[1] = "Toyata"

print(cars)

x = len(cars)

print(x)

cars.append("Honda")

print(cars)

#cars.clear

#print(cars)

cars.sort(reverse=True)

print(cars)
# Out:
# Backup data ['Ford', 'Volvo', 'BMW']
# ['Ford', 'Volvo', 'BMW']
# ['Ford', 'Toyata', 'BMW']
# 3
# ['Ford', 'Toyata', 'BMW', 'Honda']
# ['Toyata', 'Honda', 'Ford', 'BMW']

# %%
cars.insert(2, "Mitsubishi")
print(cars)

cars.pop(3)
print(cars)

cars.remove('Ford')
print(cars)
# Out:
# ['Ford', 'Toyata', 'Mitsubishi', 'Mitsubishi', 'Honda']
# ['Ford', 'Toyata', 'Mitsubishi', 'Honda']
# ['Toyata', 'Mitsubishi', 'Honda']
